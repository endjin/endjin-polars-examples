# %%
import logging
from pathlib import Path
from data_importers import LandRegistryImporter

logging.basicConfig(level=logging.INFO, format="%(levelname)s - %(name)s - %(message)s", force=True)

# %%
DOWNLOAD_PATH = Path("../../data/land_registry_data")
DOWNLOAD_PATH.mkdir(parents=True, exist_ok=True)

# %%
land_registry_importer = LandRegistryImporter(
    raw_data_download_path=str(DOWNLOAD_PATH),
    storage_options={},
    number_of_years=10
    )
land_registry_importer.download_land_registry_data()
# Out:
# INFO - data_importers.land_registry_importer - Starting download of Land Registry data...
# INFO - data_importers.land_registry_importer - Number of files to download: 10
# INFO - data_importers.land_registry_importer - File pp-2025.csv already exists at ../../data/land_registry_data/pp-2025.csv. Skipping download.
# INFO - data_importers.land_registry_importer - File pp-2024.csv already exists at ../../data/land_registry_data/pp-2024.csv. Skipping download.
# INFO - data_importers.land_registry_importer - Downloaded file 3 of 10: filename pp-2023.csv to: ../../data/land_registry_data/pp-2023.csv
# INFO - data_importers.land_registry_importer - Downloaded file 4 of 10: filename pp-2022.csv to: ../../data/land_registry_data/pp-2022.csv
# INFO - data_importers.land_registry_importer - Downloaded file 5 of 10: filename pp-2021.csv to: ../../data/land_registry_data/pp-2021.csv
# ...
